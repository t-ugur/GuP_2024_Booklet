# %%
import pandas as pd
import numpy as np

# %%
pug_df = pd.read_excel("./PuG_Prizes.xlsx")
pug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       610 non-null    int64
#  1   Type                     610 non-null    object
#  2   Topic                    610 non-null    object
#  3   Title                    610 non-null    object
#  4   Mantelabstract           610 non-null    object
#  5   Abstract                 610 non-null    object
#  6   Submitter first name     610 non-null    object
#  7   Submitter last name      610 non-null    object
#  8   Submitter (affiliation)  610 non-null    object
#  9   Submitter (email)        605 non-null    object
#  10  Gender                   610 non-null    object
#  11  Young scientist          610 non-null    object
#  12  IGOR Prize               610 non-null    object
#  13  Posterblitz              610 non-null    object
# ...

# %%
l,c = np.unique(pug_df["Type"], return_counts=True)
l,c
# Out:
# (array(['Poster', 'Poster ', 'Potster', 'Symposium'], dtype=object),
#  array([276, 120,   1, 213], dtype=int64))

# %%
symp_df = pug_df.loc[pug_df["Type"] == "Symposium"]
symp_df.T.to_json(path_or_buf="./PuG24_symposium.json")
symp_df.T
# Out:
#                                                                        12   \
# Id                                                                      19
# Type                                                             Symposium
# Topic                                          Learning, Memory, and Sleep
# Title                    Mnemonic processing of immersive environments:...
# Mantelabstract                                                         YES
# Abstract                 The majority of everyday memories is based on ...
# Submitter first name                                                Joanna
# Submitter last name                                                 Kisker
# Submitter (affiliation)                              Universität Osnabrück
# Submitter (email)                          joanna.kisker@uni-osnabrueck.de
# Gender                                                              female
# ...

# %%
post_df = pug_df.loc[pug_df["Type"] != "Symposium"]
post_df.T.to_json(path_or_buf="./PuG24_poster.json")
post_df.T
# Out:
#                                                                        0    \
# Id                                                                       6
# Type                                                                Poster
# Topic                                          Learning, Memory, and Sleep
# Title                    Learning from Emotional Feedback in Younger an...
# Mantelabstract                                                          NO
# Abstract                 As individuals age, the process of learning te...
# Submitter first name                                         Jana Isabelle
# Submitter last name                                             Braunwarth
# Submitter (affiliation)                    Bergische Universität Wuppertal
# Submitter (email)                              braunwarth@uni-wuppertal.de
# Gender                                                              female
# ...
